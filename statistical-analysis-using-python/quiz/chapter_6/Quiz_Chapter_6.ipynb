# %% [markdown]
# # 6장 의사 결정을 하기 위한 절차 (의사결정) Quiz

# %%
import numpy as np
import pandas as pd
import pickle
from scipy import stats
from statsmodels.stats.weightstats import ttest_ind

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 6-1. 데이터셋 불러오기

# %%
df = pd.read_csv("val_for_quiz.csv", index_col=0).reset_index(drop=True)
df.dropna(inplace=True)
df
# Out:
#       year  month  day  time  minute stn_id  ws10_deg  ws10_ms    ta   re  \
# 0        K     12   21     2      30      A      57.5      4.2  -0.7  0.0
# 2        I     11    8    18      40      E     324.7      3.9  14.7  0.0
# 3        J      5   22     1      50      A     240.5      1.9  15.7  0.0
# 4        K      1    4    21      30      E     319.5      3.7   4.8  0.0
# 5        I      3    5    13      20      B     240.1      3.7   1.5  0.0
# ...    ...    ...  ...   ...     ...    ...       ...      ...   ...  ...
# 78344    I      9   25    10      20      D       4.4      5.0  21.4  0.0
# 78345    J      7   13     9       0      B     352.5      0.5  25.5  0.0
# 78346    K     11    7    21      50      A      82.4      0.9  10.9  0.0
# 78347    J     11    3    20      10      D     189.3      1.4  13.6  0.0
# 78348    I      5   20     0       0      A      48.3      1.7   8.6  0.0
#
#          hm  sun10    ts   vis1  class  is_fog  dew_point  dew_reached  \
# 0      60.6   0.00  -1.3  20000      4       0  -7.133154            0
# 2      26.5   0.00  12.2  50000      4       0  -3.753022            0
# 3      86.1   0.00  15.6  10650      4       0  13.456121            0
# 4      32.4   0.00   0.8  35330      4       0  -9.839557            0
# 5      42.6   0.50  -0.2  17635      4       0  -9.450206            0
# ...     ...    ...   ...    ...    ...     ...        ...          ...
# 78344  63.1   0.41  30.5  20000      4       0  14.314440            0
# 78345  74.0   0.15  30.9  10300      4       0  20.671669            0
# 78346  54.9   0.00   9.8  24650      4       0   2.473210            0
# 78347  68.0   0.00  12.2   7894      4       0   7.992854            0
# 78348  79.0   0.00  11.0  20000      4       0   5.279639            0
#
#        temp_diff ws10_dir       t_td
# 0            0.6       NE   6.433154
# 2            2.5       NW  18.453022
# 3            0.1       SW   2.243879
# 4            4.0       NW  14.639557
# 5            1.7       SW  10.950206
# ...          ...      ...        ...
# 78344       -9.1        N   7.085560
# 78345       -5.4        N   4.828331
# 78346        1.1        E   8.426790
# 78347        1.4        S   5.607146
# 78348       -2.4       NE   3.320361
#
# [74908 rows x 21 columns]

# %% [markdown]
# ## 6-2. 두 모집단 간의 차에 대한 검정

# %% [markdown]
# - `year` 컬럼의 J, K에 따른 `ta` 컬럼의 평균값에는 차이가 있다?

# %%
df.groupby(["year"])["ta"].describe()
# Out:
#         count       mean        std        min  25%   50%   75%   max
# year
# I     25422.0  13.606261   9.400612 -15.482900  5.9  14.0  21.5  36.9
# J     25242.0  14.290810   9.610955 -13.179149  6.9  15.0  22.2  36.2
# K     24244.0  14.112155  10.185157 -14.400000  5.9  15.1  22.8  37.2

# %%
# 연도에 따른 ta 컬럼을 시각화해주세요

# %% [markdown]
# ### 6-2-1. 정규성 검사

# %%
# 정규성 검사

ta_j = df[(df["year"]=="J")]["ta"]
ta_k = df[(df["year"]=="K")]["ta"]

# 적절한 정규성 검사를 시행해주세요

# %%
# 정규성 검사 결과의 p-value를 표현해주세요

# %%
# 정규성 결과에 따라 __에 O, X를 넣어주세요
print("J년의 ta 컬럼은 정규분포를 따른다 : __")
print("K년의 ta 컬럼은 정규분포를 따른다 : __")
# Out:
# J년의 ta 컬럼은 정규분포를 따른다 : __
# K년의 ta 컬럼은 정규분포를 따른다 : __

# %% [markdown]
# ### 6-2-2. 등분산성 검사

# %%
# 정규성을 만족한다면, 등분산성 검사를 시행해주세요
# 정규성을 만족하지 못한다면, 해당 부분을 스킵하고 비모수적 검정을 진행해주세요

# %% [markdown]
# ### 6-2-3. 두 모집단의 평균차 검정

# %%
# 앞선 정규성, 등분산성 검사의 결과에 따라, 두 모집단의 평균차를 검정해주세요

# %% [markdown]
# ## 6-3. 짝으로 된 자료에 대한 검정
# - I년의 `is_fog` 여부에 따라, 안개가 꼈을 때 `ts`가 내려갔을까요?

# %%
df_i = df[df["year"]=="I"]
df_i.head(3)
# Out:
#   year  month  day  time  minute stn_id  ws10_deg  ws10_ms    ta   re    hm  \
# 2    I     11    8    18      40      E     324.7      3.9  14.7  0.0  26.5
# 5    I      3    5    13      20      B     240.1      3.7   1.5  0.0  42.6
# 8    I      7   22    20      40      B     148.0      0.8  22.1  1.0  92.9
#
#    sun10    ts   vis1  class  is_fog  dew_point  dew_reached  temp_diff  \
# 2    0.0  12.2  50000      4       0  -3.753022            0        2.5
# 5    0.5  -0.2  17635      4       0  -9.450206            0        1.7
# 8    0.0  23.2   4963      4       0  20.933320            0       -1.1
#
#   ws10_dir       t_td
# 2       NW  18.453022
# 5       SW  10.950206
# 8       SE   1.166680

# %%
# 안개 유무에 따른 ts 컬럼을 시각화해주세요

# %% [markdown]
# ### 6-3-1. 정규성 검사

# %%
# 정규성 검사
df_i_no_fog = df_i[df_i["is_fog"]==0]["ts"]
df_i_yes_fog = df_i[df_i["is_fog"]==1]["ts"]

# 적절한 정규성 검사를 시행해주세요

# %%
# 정규성 검사 결과의 p-value를 표현해주세요

# %% [markdown]
# ### 6-3-2. 등분산성 검사

# %%
# 정규성을 만족한다면, 등분산성 검사를 시행해주세요
# 정규성을 만족하지 못한다면, 해당 부분을 스킵하고 비모수적 검정을 진행해주세요

# %% [markdown]
# ### 6-2-3. 두 모집단의 평균차 검정

# %%
# 앞선 정규성, 등분산성 검사의 결과에 따라, 단측검정을 시행해주세요
